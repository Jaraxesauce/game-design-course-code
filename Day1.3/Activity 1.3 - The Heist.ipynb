# %% [markdown]
# # Activity 1.3 - The Heist
#
# Welcome to the Heist!! You are attempting to hack into a vault containing a powerful secret... You will be given a series of tasks to complete using the coding principles we've gone over in class. Successful completion of each task will yield a character of the vault's access key. There are 4 characters to unlock, and they will not be given to you in the correct order.

# %% [markdown]
# <img src="ArtAssets3/hack.jpg">

# %% [markdown]
# Once you have the access key, you must enter it into the vault by using the following command:
#
# `heist.access(password)`
#
# Where you replace the word password in the parenthesis with your attempt. In fact, we will be passing variables into methods like this multiple times throughout the challenge.
#
# Will you be the first group to finish and unlock the vault's secret???

# %% [markdown]
# ## Getting Started
#
# **DO NOT OPEN ANY OF THE .py FILES!**
#
# I've organized this page for you with different blocks for each task. One is a place for you to take notes, and the other is a place to run your code.
#
# I've given you the code to gain access to the system. Run the line below to hack in and get started.

# %%
import _src.heist as heist
heist.start()
# Out:
# Welcome to the Heist!! You are attempting to hack into a vault containing a powerful secret...
# You will be given a series of tasks to complete using the coding principles we've gone over in class.
#
# Successful completion of each task will yield a character of the vault's access key. They are not given in order.
# Once you have collected all 4 characters, you must find the correct order of them to access the vault and complete the hack.
#
# For initializing the first system, you will be rewarded a character.
# .
#
# .
#
# .
#
# The first character is &
#
# To access the next task, enter the following command: heist.loops.start()

# %% [markdown]
# ### Task 2:
#
# **Notes:**

# %%
heist.loops.start()
# Out:
# This firewall can be surpassed by brute force. To do so, you must call the following function 1001 times:
#
# hack()
#
# However, you must figure out the proper syntax for calling this function. Good Luck!

# %%
for x in range(1001):
    heist.loops.hack()
# Out:
# Congratulations! You've successfully hacked once. Now you need to hack 1000 more times...
#
# That's 100 hacks... 10% complete
#
# 20.0% complete...
# 30.0% complete...
# 40.0% complete...
# 50.0% complete...
# 60.0% complete...
# 70.0% complete...
# 80.0% complete...
# 90.0% complete...
# Task completed. The next characer: 5
# For your next task, run heist.numberPatch.start()

# %% [markdown]
# ### Task 3:
#
# **Notes:**

# %%
heist.numberPatch.start()
# Out:
# This task is a bit more tricky... We have 8 numbers in a list that should all be the same, but one of them is bigger than the others.
# You must determine which of these numbers is the biggest, and you can only do so by comparing the sums of other numbers a maximium of 2 times before the system resets.
# If you select the wrong number, the system will lock you out for 1 minute before reseting to try again.
# To compare sums, you must enter the indices of the numbers in the list you wish to add for the first sum, then again for the second. You may add any number of the numbers together.
#
#
# The Indices: [0, 1, 2, 3, 4, 5, 6, 7]
# Input your two sets (lists) of number indices to be weighed, one at a time. They should look like this - XXXX - and may be up to 8 long. The X's represent the indices of the number in the list of numbers.
# The first set of numbers, ['0', '1', '2'] has a smaller sum than the second set of numbers, ['3', '4', '5']
#
# The Indices: [0, 1, 2, 3, 4, 5, 6, 7]
# Input your two sets (lists) of number indices to be weighed, one at a time. They should look like this - XXXX - and may be up to 8 long. The X's represent the indices of the number in the list of numbers.
# The first set of numbers, ['3'] has a larger sum than the second set of numbers, ['4']
#
# Repairing list....
# Repair successful, access granted...
# The next character is Y
# To begin the next challenge, input heist.fuseBypass.start()

# %% [markdown]
# ### Task 4:
#
# **Notes:**

# %%
heist.fuseBypass.start()
# Out:
# To unlock the next character in the password, we'll need to bypass a fuse in the computer system.
# The fuses are numbered 0-999. To test a fuse, you must enter which fuse to test in the parenthesis of heist.fuseBypass.test() and run.
# If you test a fuse higher than the target, the fuse will blow and the test will return False. If you test a fuse lower than the target, the test will return True
# You only get 2 blown fuses before you have to commit to the bypass.
#
# To bypass the target, run heist.fuseBypass.bypass()
# If you guess wrong, the system will reset, and the bypass fuse will change.
#
# Use what you know of python to write some code to help you test as many fuses as possible quickly. If you take too many attempts,
# the code will tell you whether or not you got the right fuse, but will make you try again to guess faster
# Good Luck!

# %%
fuseIsSafe = True
x = -1

while(fuseIsSafe):
    x += 2
    fuseIsSafe = heist.fuseBypass.test(x)
else:
    fuseIsSafe = heist.fuseBypass.test(x - 1)
    if fuseIsSafe:
        print("Target Fuse: "+str(x - 1))
    else:
        print("Target Fuse: "+str(x - 2))
        
heist.fuseBypass.bypass()
# Out:
# Nothing happened at 1.
#
# Nothing happened at 3.
#
# Nothing happened at 5.
#
# Nothing happened at 7.
#
# Nothing happened at 9.
#
# Nothing happened at 11.
#
# Nothing happened at 13.
#
# Nothing happened at 15.
#
# Nothing happened at 17.
#
# Nothing happened at 19.
#
# Nothing happened at 21.
#
# Nothing happened at 23.
#
# Nothing happened at 25.
#
# Nothing happened at 27.
#
# Nothing happened at 29.
#
# Nothing happened at 31.
#
# Nothing happened at 33.
#
# Nothing happened at 35.
#
# Nothing happened at 37.
#
# Nothing happened at 39.
#
# Nothing happened at 41.
#
# Nothing happened at 43.
#
# Nothing happened at 45.
#
# Nothing happened at 47.
#
# Nothing happened at 49.
#
# Nothing happened at 51.
#
# Nothing happened at 53.
#
# Nothing happened at 55.
#
# Nothing happened at 57.
#
# Nothing happened at 59.
#
# Nothing happened at 61.
#
# Nothing happened at 63.
#
# Nothing happened at 65.
#
# Nothing happened at 67.
#
# Nothing happened at 69.
#
# Nothing happened at 71.
#
# Nothing happened at 73.
#
# Nothing happened at 75.
#
# Nothing happened at 77.
#
# Nothing happened at 79.
#
# Nothing happened at 81.
#
# Nothing happened at 83.
#
# Nothing happened at 85.
#
# Nothing happened at 87.
#
# Nothing happened at 89.
#
# Nothing happened at 91.
#
# Nothing happened at 93.
#
# Nothing happened at 95.
#
# Nothing happened at 97.
#
# Nothing happened at 99.
#
# Nothing happened at 101.
#
# Nothing happened at 103.
#
# Nothing happened at 105.
#
# Nothing happened at 107.
#
# Nothing happened at 109.
#
# Nothing happened at 111.
#
# Nothing happened at 113.
#
# Nothing happened at 115.
#
# Nothing happened at 117.
#
# Nothing happened at 119.
#
# Nothing happened at 121.
#
# Nothing happened at 123.
#
# Nothing happened at 125.
#
# Nothing happened at 127.
#
# Nothing happened at 129.
#
# Nothing happened at 131.
#
# Nothing happened at 133.
#
# Nothing happened at 135.
#
# Nothing happened at 137.
#
# Nothing happened at 139.
#
# Nothing happened at 141.
#
# Nothing happened at 143.
#
# Nothing happened at 145.
#
# Nothing happened at 147.
#
# Nothing happened at 149.
#
# Nothing happened at 151.
#
# Nothing happened at 153.
#
# Nothing happened at 155.
#
# Nothing happened at 157.
#
# Nothing happened at 159.
#
# Nothing happened at 161.
#
# Nothing happened at 163.
#
# Nothing happened at 165.
#
# Nothing happened at 167.
#
# Nothing happened at 169.
#
# Nothing happened at 171.
#
# Nothing happened at 173.
#
# Nothing happened at 175.
#
# Nothing happened at 177.
#
# Nothing happened at 179.
#
# Nothing happened at 181.
#
# Nothing happened at 183.
#
# Nothing happened at 185.
#
# Nothing happened at 187.
#
# Nothing happened at 189.
#
# Nothing happened at 191.
#
# Nothing happened at 193.
#
# Nothing happened at 195.
#
# Nothing happened at 197.
#
# Nothing happened at 199.
#
# Nothing happened at 201.
#
# Nothing happened at 203.
#
# Nothing happened at 205.
#
# Nothing happened at 207.
#
# Nothing happened at 209.
#
# Nothing happened at 211.
#
# Nothing happened at 213.
#
# Nothing happened at 215.
#
# Nothing happened at 217.
#
# Nothing happened at 219.
#
# Nothing happened at 221.
#
# Nothing happened at 223.
#
# Nothing happened at 225.
#
# Nothing happened at 227.
#
# Nothing happened at 229.
#
# Nothing happened at 231.
#
# Nothing happened at 233.
#
# Nothing happened at 235.
#
# Nothing happened at 237.
#
# Nothing happened at 239.
#
# Nothing happened at 241.
#
# Nothing happened at 243.
#
# Nothing happened at 245.
#
# Nothing happened at 247.
#
# Nothing happened at 249.
#
# Nothing happened at 251.
#
# Nothing happened at 253.
#
# Nothing happened at 255.
#
# Nothing happened at 257.
#
# Nothing happened at 259.
#
# Nothing happened at 261.
#
# Nothing happened at 263.
#
# Nothing happened at 265.
#
# Nothing happened at 267.
#
# Nothing happened at 269.
#
# Nothing happened at 271.
#
# Nothing happened at 273.
#
# Nothing happened at 275.
#
# Nothing happened at 277.
#
# Nothing happened at 279.
#
# Nothing happened at 281.
#
# Nothing happened at 283.
#
# Nothing happened at 285.
#
# Nothing happened at 287.
#
# Nothing happened at 289.
#
# Nothing happened at 291.
#
# Nothing happened at 293.
#
# Nothing happened at 295.
#
# Nothing happened at 297.
#
# Nothing happened at 299.
#
# Nothing happened at 301.
#
# Nothing happened at 303.
#
# Nothing happened at 305.
#
# Nothing happened at 307.
#
# Nothing happened at 309.
#
# Nothing happened at 311.
#
# Nothing happened at 313.
#
# Nothing happened at 315.
#
# Nothing happened at 317.
#
# Nothing happened at 319.
#
# Nothing happened at 321.
#
# Nothing happened at 323.
#
# Nothing happened at 325.
#
# Nothing happened at 327.
#
# Nothing happened at 329.
#
# Nothing happened at 331.
#
# Nothing happened at 333.
#
# Nothing happened at 335.
#
# Nothing happened at 337.
#
# Nothing happened at 339.
#
# Nothing happened at 341.
#
# Nothing happened at 343.
#
# Nothing happened at 345.
#
# Nothing happened at 347.
#
# Nothing happened at 349.
#
# Nothing happened at 351.
#
# Nothing happened at 353.
#
# Nothing happened at 355.
#
# Nothing happened at 357.
#
# Nothing happened at 359.
#
# Nothing happened at 361.
#
# Nothing happened at 363.
#
# Nothing happened at 365.
#
# Nothing happened at 367.
#
# Nothing happened at 369.
#
# Nothing happened at 371.
#
# Nothing happened at 373.
#
# Nothing happened at 375.
#
# Nothing happened at 377.
#
# Nothing happened at 379.
#
# Nothing happened at 381.
#
# Nothing happened at 383.
#
# Nothing happened at 385.
#
# Nothing happened at 387.
#
# Nothing happened at 389.
#
# Nothing happened at 391.
#
# Nothing happened at 393.
#
# Nothing happened at 395.
#
# Nothing happened at 397.
#
# Nothing happened at 399.
#
# Nothing happened at 401.
#
# Nothing happened at 403.
#
# Nothing happened at 405.
#
# Nothing happened at 407.
#
# Nothing happened at 409.
#
# Nothing happened at 411.
#
# Nothing happened at 413.
#
# Nothing happened at 415.
#
# Nothing happened at 417.
#
# Nothing happened at 419.
#
# Nothing happened at 421.
#
# Nothing happened at 423.
#
# Nothing happened at 425.
#
# Nothing happened at 427.
#
# Nothing happened at 429.
#
# Nothing happened at 431.
#
# Nothing happened at 433.
#
# Nothing happened at 435.
#
# Nothing happened at 437.
#
# Nothing happened at 439.
#
# Nothing happened at 441.
#
# Nothing happened at 443.
#
# Nothing happened at 445.
#
# Nothing happened at 447.
#
# Nothing happened at 449.
#
# Nothing happened at 451.
#
# Nothing happened at 453.
#
# Nothing happened at 455.
#
# Nothing happened at 457.
#
# Nothing happened at 459.
#
# Nothing happened at 461.
#
# Nothing happened at 463.
#
# Nothing happened at 465.
#
# Nothing happened at 467.
#
# Nothing happened at 469.
#
# Nothing happened at 471.
#
# Nothing happened at 473.
#
# Nothing happened at 475.
#
# Nothing happened at 477.
#
# Nothing happened at 479.
#
# Nothing happened at 481.
#
# Nothing happened at 483.
#
# Nothing happened at 485.
#
# Nothing happened at 487.
#
# Nothing happened at 489.
#
# Nothing happened at 491.
#
# Nothing happened at 493.
#
# Nothing happened at 495.
#
# Nothing happened at 497.
#
# Nothing happened at 499.
#
# Nothing happened at 501.
#
# Nothing happened at 503.
#
# Nothing happened at 505.
#
# Nothing happened at 507.
#
# Nothing happened at 509.
#
# Nothing happened at 511.
#
# Nothing happened at 513.
#
# Nothing happened at 515.
#
# Nothing happened at 517.
#
# Nothing happened at 519.
#
# Nothing happened at 521.
#
# Nothing happened at 523.
#
# Nothing happened at 525.
#
# Nothing happened at 527.
#
# Nothing happened at 529.
#
# Nothing happened at 531.
#
# Nothing happened at 533.
#
# Nothing happened at 535.
#
# Nothing happened at 537.
#
# Nothing happened at 539.
#
# Nothing happened at 541.
#
# Nothing happened at 543.
#
# Nothing happened at 545.
#
# Nothing happened at 547.
#
# Nothing happened at 549.
#
# Nothing happened at 551.
#
# Nothing happened at 553.
#
# Nothing happened at 555.
#
# Nothing happened at 557.
#
# Nothing happened at 559.
#
# Nothing happened at 561.
#
# Nothing happened at 563.
#
# Nothing happened at 565.
#
# Nothing happened at 567.
#
# Nothing happened at 569.
#
# Nothing happened at 571.
#
# Nothing happened at 573.
#
# Nothing happened at 575.
#
# Nothing happened at 577.
#
# Nothing happened at 579.
#
# Nothing happened at 581.
#
# Nothing happened at 583.
#
# Nothing happened at 585.
#
# Nothing happened at 587.
#
# Nothing happened at 589.
#
# Nothing happened at 591.
#
# Nothing happened at 593.
#
# Nothing happened at 595.
#
# Nothing happened at 597.
#
# Nothing happened at 599.
#
# Nothing happened at 601.
#
# Nothing happened at 603.
#
# Nothing happened at 605.
#
# Nothing happened at 607.
#
# Nothing happened at 609.
#
# Nothing happened at 611.
#
# Nothing happened at 613.
#
# Nothing happened at 615.
#
# Nothing happened at 617.
#
# Nothing happened at 619.
#
# Nothing happened at 621.
#
# Nothing happened at 623.
#
# Nothing happened at 625.
#
# Nothing happened at 627.
#
# Nothing happened at 629.
#
# Nothing happened at 631.
#
# Nothing happened at 633.
#
# Nothing happened at 635.
#
# Nothing happened at 637.
#
# Nothing happened at 639.
#
# Nothing happened at 641.
#
# Nothing happened at 643.
#
# Nothing happened at 645.
#
# Nothing happened at 647.
#
# Nothing happened at 649.
#
# Nothing happened at 651.
#
# Nothing happened at 653.
#
# Nothing happened at 655.
#
# Nothing happened at 657.
#
# Nothing happened at 659.
#
# Nothing happened at 661.
#
# Nothing happened at 663.
#
# Nothing happened at 665.
#
# Nothing happened at 667.
#
# Nothing happened at 669.
#
# Nothing happened at 671.
#
# Nothing happened at 673.
#
# Nothing happened at 675.
#
# Nothing happened at 677.
#
# Nothing happened at 679.
#
# Nothing happened at 681.
#
# Nothing happened at 683.
#
# Nothing happened at 685.
#
# Nothing happened at 687.
#
# Nothing happened at 689.
#
# Nothing happened at 691.
#
# Nothing happened at 693.
#
# Nothing happened at 695.
#
# Nothing happened at 697.
#
# Nothing happened at 699.
#
# Nothing happened at 701.
#
# Nothing happened at 703.
#
# Nothing happened at 705.
#
# Nothing happened at 707.
#
# Nothing happened at 709.
#
# Nothing happened at 711.
#
# Nothing happened at 713.
#
# Nothing happened at 715.
#
# Nothing happened at 717.
#
# Nothing happened at 719.
#
# Nothing happened at 721.
#
# Nothing happened at 723.
#
# Nothing happened at 725.
#
# Nothing happened at 727.
#
# Nothing happened at 729.
#
# Nothing happened at 731.
#
# Nothing happened at 733.
#
# Nothing happened at 735.
#
# Nothing happened at 737.
#
# Nothing happened at 739.
#
# Nothing happened at 741.
#
# Nothing happened at 743.
#
# Nothing happened at 745.
#
# Nothing happened at 747.
#
# Nothing happened at 749.
#
# Nothing happened at 751.
#
# Nothing happened at 753.
#
# Nothing happened at 755.
#
# Nothing happened at 757.
#
# Nothing happened at 759.
#
# Nothing happened at 761.
#
# Nothing happened at 763.
#
# Nothing happened at 765.
#
# Nothing happened at 767.
#
# Nothing happened at 769.
#
# Nothing happened at 771.
#
# Nothing happened at 773.
#
# Nothing happened at 775.
#
# Nothing happened at 777.
#
# Nothing happened at 779.
#
# Nothing happened at 781.
#
# Nothing happened at 783.
#
# Nothing happened at 785.
#
# Nothing happened at 787.
#
# Nothing happened at 789.
#
# Nothing happened at 791.
#
# Nothing happened at 793.
#
# Nothing happened at 795.
#
# Nothing happened at 797.
#
# Nothing happened at 799.
#
# Nothing happened at 801.
#
# Nothing happened at 803.
#
# Nothing happened at 805.
#
# Nothing happened at 807.
#
# Nothing happened at 809.
#
# Nothing happened at 811.
#
# Nothing happened at 813.
#
# Nothing happened at 815.
#
# Nothing happened at 817.
#
# Nothing happened at 819.
#
# Nothing happened at 821.
#
# Nothing happened at 823.
#
# Nothing happened at 825.
#
# Nothing happened at 827.
#
# Nothing happened at 829.
#
# Nothing happened at 831.
#
# Nothing happened at 833.
#
# Nothing happened at 835.
#
# Nothing happened at 837.
#
# Nothing happened at 839.
#
# Nothing happened at 841.
#
# Nothing happened at 843.
#
# Nothing happened at 845.
#
# Nothing happened at 847.
#
# Nothing happened at 849.
#
# Nothing happened at 851.
#
# Nothing happened at 853.
#
# Nothing happened at 855.
#
# Nothing happened at 857.
#
# Nothing happened at 859.
#
# Nothing happened at 861.
#
# Nothing happened at 863.
#
# Nothing happened at 865.
#
# Nothing happened at 867.
#
# Nothing happened at 869.
#
# Nothing happened at 871.
#
# Nothing happened at 873.
#
# Nothing happened at 875.
#
# Nothing happened at 877.
#
# Nothing happened at 879.
#
# Nothing happened at 881.
#
# Nothing happened at 883.
#
# Nothing happened at 885.
#
# You blew fuse 887
#
# Nothing happened at 886.
#
# Target Fuse: 886
# Correct fuse bypass detected....
#
# Authorization verified. Bypassing...
#
# The next character is 7
# Now, you must unscramble the characters to find the passcode. Enter the password into the parenthesis in heist.access(). If you guess the password correctly, it will return 'True', otherwise it will return 'False'.
# You may have to write some code to guess the correct combination

# %% [markdown]
# ### Enter Acess Key:
#
# **Notes:**

# %%
characters = ['&', '5', '7', 'Y']
passwordsTried = 0

for firstLetter in characters:
    for secondLetter in characters:
        for thirdLetter in characters:
            for fourthLetter in characters:
                password = firstLetter + secondLetter + thirdLetter + fourthLetter
                heist.access(password)
                passwordsTried += 1

print("We tried "+str(passwordsTried)+" passwords with this loop")
# Out:
# Hacking attempt detected... Password is key plus 4 more characters: GL8T... These are not in order. Try again with all 8 characters...
# We tried 256 passwords with this loop

# %%
characters = ('&', '5', 'Y', '7', 'G', 'L', '8', 'T')
baseEight = [0,0,0,0,0,0,0,0]
numberOfChecks = 0

unlocked = False

while(not unlocked):
    
    currentSet = baseEight
    
    if len(baseEight) == len(set(currentSet)): 
        password = characters[baseEight[0]]+characters[baseEight[1]]+characters[baseEight[2]]+characters[baseEight[3]]+characters[baseEight[4]]+characters[baseEight[5]]+characters[baseEight[6]]+characters[baseEight[7]]
        unlocked = heist.access(password)
        numberOfChecks += 1
        
    counter = 1
    for i in range(8):
        if (baseEight[i] < 7 or counter == 0):
            baseEight[i] += counter
            counter = 0
            break
        else:
            baseEight[i] = 0
            counter = 1
            
    if baseEight == [7,7,7,7,7,7,7,7]:
        break
else:        
    print(numberOfChecks)
# Out:
# Password authentication complete...
# Retrieving data...
# .
#
# .
#
# .
#
#
# Congratulations! You've successfully unlocked the vault. Don't spoil the Rickroll for anyone else ;)
# 13103
